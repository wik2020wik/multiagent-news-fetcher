# %%
# news_graph_multi.py
import os, asyncio, datetime, json, math
from typing import List, Optional, TypedDict, Dict, Any
import feedparser, httpx, trafilatura
from dotenv import load_dotenv
from openai import OpenAI
import nest_asyncio
nest_asyncio.apply()
from langgraph.graph import StateGraph

# %%
def arun(coro):  # helper to run async in notebooks
    return asyncio.get_event_loop().run_until_complete(coro)

# %%
# -----------------------------------------------------------------------------
# Setup (same as your original, kept stable)
# -----------------------------------------------------------------------------
load_dotenv()
OPENAI_MODEL = os.getenv("OPENAI_MODEL", "gpt-4o")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise RuntimeError("Set OPENAI_API_KEY in your .env")

oai = OpenAI(api_key=OPENAI_API_KEY)

EMBED_MODEL = os.getenv("OPENAI_EMBED_MODEL", "text-embedding-3-small")
EMBED_CACHE_PATH = os.getenv("EMBED_CACHE_PATH", "keyword_embs_1.json")
EMBED_SIM_THRESHOLD = float(os.getenv("EMBED_SIM_THRESHOLD", "0.75"))
SCORING_MODE = os.getenv("SCORING_MODE", "embedding")  # kept for future use

# %%
FEEDS: Dict[str, List[str]] = {
    "AI": [
        "https://openai.com/blog/rss/",
        "https://deepmind.com/blog/feed/basic/",
        "https://paperswithcode.com/feeds/latest",
    ],
    "Tech": [
        "https://techcrunch.com/feed/",
        "https://www.theverge.com/rss/index.xml",
        "https://www.wired.com/feed/rss"
    ],
    "Finance": [
        "https://www.marketwatch.com/feeds/topstories",
        "http://feeds.reuters.com/reuters/financialsNews",
        "https://seekingalpha.com/market_currents.xml"
    ],
}

KEYWORDS = [
    "AI", "NVIDIA", "OPENAI", "APPLE", "GOOGLE", "TESLA", "FACEBOOK", "AMAZON", "SAMSUNG",
    "chip", "ECB", "inflation", "etf", "Bitcoin", "crypto", "BTC", "GPT"
    "TRUMP", "POWELL", "Warren Buffet", "MUSK", "Dimon", "Solomon",
    "Soros", "Dalio", "Ackman"
]
MAX_TOTAL = 18
TOP_N = 9

# %%
def keyword_score(title: str, text: str):
    base = (title + " " + text[:800]).lower()
    score = sum(2.0 if kw.isupper() else 1.0
                for kw in KEYWORDS if kw.lower() in base)

# %%
# -----------------------------------------------------------------------------
# Minimal embedding cache support (re-using your approach)
# -----------------------------------------------------------------------------
def _cosine_sim(a: List[float], b: List[float]) -> float:
    dot = sum(x*y for x, y in zip(a, b))
    na = math.sqrt(sum(x*x for x in a))
    nb = math.sqrt(sum(y*y for y in b))
    return dot / (na * nb) if na and nb else 0.0

def _load_keyword_cache() -> Dict[str, List[float]]:
    if os.path.exists(EMBED_CACHE_PATH):
        try:
            with open(EMBED_CACHE_PATH, "r", encoding="utf-8") as f:
                data = json.load(f)
                return {k: v for k, v in data.items() if k in KEYWORDS}
        except Exception:
            return {}
    return {}

def _save_keyword_cache(cache: Dict[str, List[float]]):
    try:
        with open(EMBED_CACHE_PATH, "w", encoding="utf-8") as f:
            json.dump(cache, f)
        print(f"✅ Keyword cache saved to {EMBED_CACHE_PATH} ({len(cache)} entries).")
    except Exception as e:
        print(f"⚠️ Warning: failed to save keyword cache to {EMBED_CACHE_PATH}: {e}")


def _embed_text(txt: str) -> List[float]:
    resp = oai.embeddings.create(model=EMBED_MODEL, input=txt)
    return resp.data[0].embedding

_KEYWORD_EMBS: Dict[str, List[float]] = _load_keyword_cache()
_missing = [kw for kw in KEYWORDS if kw not in _KEYWORD_EMBS]
if _missing:
    for kw in _missing:
        _KEYWORD_EMBS[kw] = _embed_text(kw)
    _save_keyword_cache(_KEYWORD_EMBS)
# Out:
# ✅ Keyword cache saved to keyword_embs_1.json (25 entries).

# %%
# -----------------------------------------------------------------------------
# State schema
# -----------------------------------------------------------------------------
class Article(TypedDict, total=False):
    title: str
    link: str
    category: str
    text: str
    summary: Optional[str]
    score: float
    risk: Optional[str]         # added: critic’s risk note
    grounded: Optional[bool]    # added: critic’s grounding verdict
    entities: Optional[Dict[str, Any]]  # added: tagger’s JSON (companies/people/tickers/topics)

class AgentState(TypedDict):
    articles: List[Article]
    top_n: int
    digest_md: Optional[str]

# %%
# -------------------------------------------------------------------
# Fetcher Node (balanced per category with round-robin)
# -------------------------------------------------------------------
async def fetcher_node(state: AgentState) -> AgentState:
    items: List[Article] = []

    # Step 1. Collect raw feed entries
    for cat, feeds in FEEDS.items():
        for url in feeds:
            f = feedparser.parse(url)
            for e in f.entries[:6]:  # cap per feed to avoid overload
                link = getattr(e, "link", None)
                title = getattr(e, "title", "Untitled")
                if not link:
                    continue
                items.append({
                    "title": title,
                    "link": link,
                    "category": cat,
                    "text": "",
                    "summary": None,
                    "score": 0.0,
                })

    # Step 2. Deduplicate
    seen, uniq = set(), []
    for it in items:
        if it["link"] in seen:
            continue
        seen.add(it["link"])
        uniq.append(it)
    items = uniq

    # Step 3. Bucket by category
    from collections import defaultdict, deque
    by_cat = defaultdict(deque)
    for it in items:
        by_cat[it["category"]].append(it)

    # Step 4. Round-robin balance up to MAX_TOTAL
    balanced, cats = [], list(by_cat.keys())
    while len(balanced) < MAX_TOTAL and any(by_cat[c] for c in cats):
        for c in cats:
            if by_cat[c] and len(balanced) < MAX_TOTAL:
                balanced.append(by_cat[c].popleft())
    items = balanced  # evenly interleaved

    # Step 5. Pull HTML + extract text
    async with httpx.AsyncClient(follow_redirects=True, timeout=15) as client:
        async def extract(it: Article):
            try:
                r = await client.get(it["link"])
                html = r.text if r.status_code == 200 else ""
                text = trafilatura.extract(
                    html,
                    include_comments=False,
                    include_tables=False
                ) or ""
                it["text"] = text
            except Exception:
                it["text"] = ""
            return it

        items = await asyncio.gather(*(extract(it) for it in items))

    # Step 6. Update state
    state["articles"] = items
    return state

# %%
import runpy, types, asyncio
mod = types.SimpleNamespace(**runpy.run_path("news_graph_multi.py"))

# %%
def arun(coro):  # helper to run async in notebooks
    return asyncio.get_event_loop().run_until_complete(coro)

# %%
state = {"articles": [], "top_n": 9, "digest_md": None}

# %%
state = arun(mod.fetcher_node(state))
print("After fetcher:", len(state["articles"]), "articles")
print("Sample title:", state["articles"][0]["title"])
print(state["articles"][0]["text"][:400])
# Out:
# After fetcher: 18 articles
# Sample title: Strengthening our Frontier Safety Framework
# Responsibility & Safety
# Strengthening our Frontier Safety Framework
# We’re expanding our risk domains and refining our risk assessment process.
# AI breakthroughs are transforming our everyday lives, from advancing mathematics, biology and astronomy to realizing the potential of personalized education. As we build increasingly powerful AI models, we’re committed to responsibly developing our technolo

# %%
for i, art in enumerate(state["articles"][:50], 1):
    print(f"\n--- Article {i} ---")
    print("Title:", art["title"])
    print("Category:", art["category"])
    print("Link:", art["link"])
    print("Text preview:", art["text"][:200], "...")
# Out:
# --- Article 1 ---
# Title: Strengthening our Frontier Safety Framework
# Category: AI
# Link: https://deepmind.google/discover/blog/strengthening-our-frontier-safety-framework/
# Text preview: Responsibility & Safety
# Strengthening our Frontier Safety Framework
# We’re expanding our risk domains and refining our risk assessment process.
# AI breakthroughs are transforming our everyday lives, fro ...
#
# --- Article 2 ---
# Title: Discovering new solutions to century-old problems in fluid dynamics
# Category: AI
# Link: https://deepmind.google/discover/blog/discovering-new-solutions-to-century-old-problems-in-fluid-dynamics/
# Text preview: Science
# Discovering new solutions to century-old problems in fluid dynamics
# Our new method could help mathematicians leverage AI techniques to tackle long-standing challenges in mathematics, physics a ...
#
# --- Article 3 ---
# Title: Gemini achieves gold-level performance at the International Collegiate Programming Contest World Finals
# Category: AI
# Link: https://deepmind.google/discover/blog/gemini-achieves-gold-level-performance-at-the-international-collegiate-programming-contest-world-finals/
# Text preview: Research
# Gemini achieves gold-medal level at the International Collegiate Programming Contest World Finals
# Gemini 2.5 Deep Think achieves breakthrough performance at the world’s most prestigious compu ...
#
# --- Article 4 ---
# Title: Using AI to perceive the universe in greater depth
# Category: AI
# Link: https://deepmind.google/discover/blog/using-ai-to-perceive-the-universe-in-greater-depth/
# Text preview: Science
# Using AI to perceive the universe in greater depth
# Our novel Deep Loop Shaping method improves control of gravitational wave observatories, helping astronomers better understand the dynamics a ...
#
# --- Article 5 ---
# Title: Image editing in Gemini just got a major upgrade
# Category: AI
# Link: https://deepmind.google/discover/blog/image-editing-in-gemini-just-got-a-major-upgrade/
# Text preview: Image editing in Gemini just got a major upgrade
# Today in the Gemini app, we're unveiling a new image editing model from Google DeepMind. People have been going bananas over it already in early previe ...
#
# --- Article 6 ---
# Title: Introducing Gemma 3 270M: The compact model for hyper-efficient AI
# Category: AI
# Link: https://deepmind.google/discover/blog/introducing-gemma-3-270m-the-compact-model-for-hyper-efficient-ai/
# Text preview: The last few months have been an exciting time for the Gemma family of open models. We introduced Gemma 3 and Gemma 3 QAT, delivering state-of-the-art performance for single cloud and desktop accelera ...
#
# --- Article 7 ---
# Title: UK police arrest man linked to ransomware attack that caused airport disruptions in Europe
# Category: Tech
# Link: https://techcrunch.com/2025/09/24/uk-police-arrest-man-linked-to-ransomware-attack-that-caused-airport-disruptions-in-europe/
# Text preview: The U.K.’s National Crime Agency (NCA) said on Wednesday that a man was arrested in connection to the ransomware attack that has caused delays and disruptions at several European airports since the we ...
#
# --- Article 8 ---
# Title: Alibaba to offer Nvidia’s physical AI development tools in its AI platform
# Category: Tech
# Link: https://techcrunch.com/2025/09/24/alibaba-to-offer-nvidias-physical-ai-development-tools-in-its-ai-platform/
# Text preview: Nvidia is on a dealmaking spree: Days after committing to taking a $5 billion stake in Intel and a whopping $100 billion investment in OpenAI, the GPU maker has now struck a partnership with China’s A ...
#
# --- Article 9 ---
# Title: Depop launches a fashion collaging tool to style Pinterest-worthy outfits
# Category: Tech
# Link: https://techcrunch.com/2025/09/24/depop-launches-a-fashion-collaging-tool-to-style-pinterest-worthy-outfits/
# Text preview: Fashion resale app Depop announced on Wednesday the launch of a new styling and collaging tool, designed specifically for users who love creating fashion collages. Named “Outfits,” the new feature pro ...
#
# --- Article 10 ---
# Title: Google’s cheaper AI Plus plan is now available in over 40 countries
# Category: Tech
# Link: https://techcrunch.com/2025/09/24/googles-cheaper-ai-plus-plan-is-now-available-in-over-40-countries/
# Text preview: Google’s new, cheaper AI Plus plan is now available in more than 40 countries, including Angola, Bangladesh, Cameroon, Côte d’Ivoire, Egypt, Ghana, Indonesia, Kenya, Mexico, Nepal, Nigeria, Philippine ...
#
# --- Article 11 ---
# Title: South Korea’s ‘Silicon Valley’ struggles to live up to its global ambitions
# Category: Tech
# Link: https://techcrunch.com/2025/09/24/south-koreas-silicon-valley-struggles-to-live-up-to-its-global-ambitions/
# Text preview: Just south of Seoul, in the city of Seongnam, sits what many call the “Silicon Valley of South Korea”: the sprawling tech complex known as Pangyo Techno Valley (PTV), which is just a 15-minute subway  ...
#
# --- Article 12 ---
# Title: How Al Gore used AI to track 660M polluters
# Category: Tech
# Link: https://techcrunch.com/2025/09/24/how-al-gore-used-ai-to-track-660m-polluters/
# Text preview: Former Vice President Al Gore’s latest project gives polluters nowhere to hide.
# The nonprofit Climate Trace, which Gore co-founded, on Wednesday launched a tool that uses AI to track fine particulate  ...
#
# --- Article 13 ---
# Title: Where has Final Fantasy Tactics been all my life?
# Category: Tech
# Link: https://www.theverge.com/entertainment/783944/final-fantasy-tactics-remake-review-square-enix-playstation
# Text preview: Final Fantasy Tactics: The Ivalice Chronicles is the strategy RPG I have been waiting for. I’ve been a Final Fantasy girlie ever since I discovered Final Fantasy VIII on my brother’s PSX demo disk whe ...
#
# --- Article 14 ---
# Title: Pokémon Legends Z-A is bringing fashion back to the franchise
# Category: Tech
# Link: https://www.theverge.com/games/784264/pokemon-legends-z-a-hands-on-fashion-nintendo-switch-2
# Text preview: In the past few Pokémon games for the Nintendo Switch, the character customization options have been so limited that they sometimes felt like an afterthought. Though there were plenty of hair styles a ...
#
# --- Article 15 ---
# Title: Lucid kicks off its Nuro-Uber robotaxi deal with delivery of first vehicle
# Category: Tech
# Link: https://www.theverge.com/transportation/784461/lucid-nuro-uber-robotaxi-first-vehicle-delivery
# Text preview: In July, Lucid, Uber, and Nuro announced a massive robotaxi deal that would see the deployment of 20,000 autonomous vehicles in the US over the next six years. But every journey begins with a single s ...
#
# --- Article 16 ---
# Title: Trump’s H-1B chaos is Europe&#8217;s opportunity to steal tech talent
# Category: Tech
# Link: https://www.theverge.com/news/784412/trump-h-1b-visa-europe-steal
# Text preview: With the US tech industry scrambling to contain the fallout of Donald Trump’s latest assault against immigrants, Europe senses blood in the water. Trump blindsided American businesses late last week w ...
#
# --- Article 17 ---
# Title: A Bluesky server issue froze some users&#8217; feeds this morning
# Category: Tech
# Link: https://www.theverge.com/news/784442/bluesky-seems-to-be-having-trouble
# Text preview: X alternative Bluesky suffered from network disruption this morning that left some users unable to see or share new posts for hours. I first noticed that my “Following” feed — which is supposed to loa ...
#
# --- Article 18 ---
# Title: Pocket Casts is showing ads to people who paid for an ad-free app
# Category: Tech
# Link: https://www.theverge.com/news/784429/pocket-casts-ads-lifetime-memberships-complaints
# Text preview: Pocket Casts is being flogged for showing advertisements to legacy users who were promised an ad-free experience. The first reports started to appear in early September in the Pocket Casts support for ...

# %%
async def summariser_node(state: AgentState) -> AgentState:
    async def do_sum(a: Article):
        if not a["text"]:
            a["summary"] = "(no extractable content)"
            a["score"] = keyword_score(a["title"], "")
            return a
        prompt = f"""You are a financial/tech news summariser.
Summarise the article in 3–5 crisp, extractive bullets (no speculation).
Add sentiment tag in square brackets at the end of the last bullet: [Bullish|Neutral|Cautious].
Use ONLY facts present in the text.

Title: {a['title']}
Text:
{a['text'][:8000]}"""
        rsp = oai.chat.completions.create(
            model=OPENAI_MODEL,
            messages=[{"role": "user", "content": prompt}],
            temperature=0.2,
        )
        a["summary"] = rsp.choices[0].message.content.strip()
        a["score"] = keyword_score(a["title"], a["text"])
        return a
    state["articles"] = await asyncio.gather(*(do_sum(a) for a in state["articles"]))
    return state

# %%
# after defining async def summariser_node(...)
state = await summariser_node(state)   # not mod.summariser_node
print("After summariser:", sum(1 for a in state["articles"] if a.get("summary")))
print(state["articles"][0]["summary"])
# Out:
# After summariser: 18
# - The latest update to the Frontier Safety Framework (FSF) focuses on identifying and mitigating severe risks from advanced AI models, building on previous iterations and collaborations with experts.
# - A new Critical Capability Level (CCL) has been introduced to address risks associated with harmful manipulation by AI models that could significantly alter beliefs and behaviors.
# - The Framework has been expanded to include protocols for misalignment risks, ensuring that AI models do not interfere with operators' control over their operations.
# - The risk assessment process has been sharpened to prioritize critical threats, with detailed analyses conducted before external launches and large-scale internal deployments.
# - The update reflects a commitment to an evidence-based approach in tracking AI risks, aiming to ensure that AI advancements benefit humanity while minimizing potential harms. [Bullish]

# %%
for i, art in enumerate(state["articles"], 1):
    print(f"\n--- Article {i} ---")
    print("Title:", art["title"])
    print("Summary:", art["summary"])
# Out:
# --- Article 1 ---
# Title: Strengthening our Frontier Safety Framework
# Summary: - The latest update to the Frontier Safety Framework (FSF) focuses on identifying and mitigating severe risks from advanced AI models, building on previous iterations and collaborations with experts.
# - A new Critical Capability Level (CCL) has been introduced to address risks associated with harmful manipulation by AI models that could significantly alter beliefs and behaviors.
# - The Framework has been expanded to include protocols for misalignment risks, ensuring that AI models do not interfere with operators' control over their operations.
# - The risk assessment process has been sharpened to prioritize critical threats, with detailed analyses conducted before external launches and large-scale internal deployments.
# - The update reflects a commitment to an evidence-based approach in tracking AI risks, aiming to ensure that AI advancements benefit humanity while minimizing potential harms. [Bullish]
#
# --- Article 2 ---
# Title: Discovering new solutions to century-old problems in fluid dynamics
# Summary: - A new method leveraging AI techniques has been developed to address long-standing challenges in fluid dynamics, mathematics, and physics.
# - The research introduces a novel family of unstable singularities in complex fluid equations, contributing to the understanding of foundational questions in fluid dynamics.
# - The study utilized Physics-Informed Neural Networks (PINNs) to achieve unprecedented accuracy in discovering these singularities, refining predictions to a high degree of precision.
# - This breakthrough is expected to usher in a new era of computer-assisted mathematics, combining deep mathematical insights with advanced AI methodologies.
# [Bullish]
#
# --- Article 3 ---
# Title: Gemini achieves gold-level performance at the International Collegiate Programming Contest World Finals
# Summary: - Gemini 2.5 Deep Think achieved gold-medal level performance at the 2025 International Collegiate Programming Contest (ICPC) World Finals, solving 10 out of 12 problems.
# - This performance follows its previous gold-medal win at the International Mathematical Olympiad (IMO) two months prior.
# - The ICPC is recognized as the oldest and most prestigious algorithmic programming competition at the college level, with participants from nearly 3000 universities across over 103 countries.
# - Gemini solved a unique problem (Problem C) that no university team managed to solve, showcasing its advanced problem-solving capabilities.
# - The achievement highlights the potential for AI to serve as a collaborative tool in software development and complex problem-solving across various fields. [Bullish]
#
# --- Article 4 ---
# Title: Using AI to perceive the universe in greater depth
# Summary: - The Deep Loop Shaping method enhances control of gravitational wave observatories, aiding astronomers in understanding the universe's dynamics and formation.
# - This AI technique reduces noise and improves stability in LIGO's feedback system, allowing for more accurate measurements of gravitational waves.
# - Deep Loop Shaping has demonstrated a noise reduction of 30 to 100 times, potentially enabling astronomers to detect hundreds more gravitational wave events annually.
# - The method has been successfully tested on LIGO's hardware, showing strong performance in both simulations and real-world applications.
# - Future applications of Deep Loop Shaping may extend beyond gravitational wave observatories to fields like aerospace, robotics, and structural engineering. [Bullish]
#
# --- Article 5 ---
# Title: Image editing in Gemini just got a major upgrade
# Summary: - Google DeepMind has launched a new image editing model integrated into the Gemini app, which is now the top-rated image editing model globally.
# - The update focuses on maintaining character likeness in edited images, ensuring that people and pets look consistently like themselves across different edits.
# - Users can upload photos and make various changes, such as costume or location alterations, blending multiple images, and applying styles from one image to another.
# - The Gemini app allows for multi-turn editing, enabling users to make iterative changes while preserving other parts of the image.
# - All images created or edited in the Gemini app will feature a visible watermark and an invisible SynthID digital watermark to indicate they are AI-generated. [Bullish]
#
# --- Article 6 ---
# Title: Introducing Gemma 3 270M: The compact model for hyper-efficient AI
# Summary: - The Gemma family of open models has recently expanded with the introduction of Gemma 3 270M, a compact model featuring 270 million parameters designed for task-specific fine-tuning.
# - Gemma 3 270M is engineered for efficiency, allowing developers to create lean and cost-effective production systems that excel in tasks like text classification and data extraction.
# - The model builds on the success of previous Gemma models, demonstrating its capabilities through real-world applications, such as Adaptive ML's collaboration with SK Telecom for multilingual content moderation.
# - Gemma 3 270M is designed to facilitate the creation of specialized models, empowering developers to innovate and customize AI solutions easily.
# - The Gemmaverse continues to grow, with downloads surpassing 200 million, highlighting the community's engagement and the potential for further innovation. [Bullish]
#
# --- Article 7 ---
# Title: UK police arrest man linked to ransomware attack that caused airport disruptions in Europe
# Summary: - A man in his forties was arrested by the U.K.’s National Crime Agency (NCA) in connection with a ransomware attack affecting several European airports.
# - The attack targeted check-in systems from Collins Aerospace, causing delays at Brussels, Berlin, Dublin, and London’s Heathrow airport.
# - The disruptions began on Friday and continued until Tuesday, when the man was arrested in West Sussex.
# - The arrested individual has been released on conditional bail, and the investigation is still in its early stages. [Cautious]
#
# --- Article 8 ---
# Title: Alibaba to offer Nvidia’s physical AI development tools in its AI platform
# Summary: - Nvidia has partnered with Alibaba to integrate its AI development tools into Alibaba's Cloud Platform for AI, focusing on robotics, self-driving cars, and connected spaces.
# - The collaboration includes Nvidia’s Physical AI software stack, which creates 3D replicas of real-world environments for training AI models.
# - Alibaba is increasing its AI investment beyond a previously set budget of $50 billion and plans to launch new data centers in Brazil, France, and the Netherlands.
# - The company also introduced Qwen 3-Max, its largest language model to date, trained on 1 trillion parameters, aimed at coding and agentic applications.
# [Bullish]
#
# --- Article 9 ---
# Title: Depop launches a fashion collaging tool to style Pinterest-worthy outfits
# Summary: - Depop has launched a new styling and collaging tool called “Outfits,” aimed at users who enjoy creating fashion collages.
# - The feature allows users to design outfits with customization options, including backgrounds and templates, and all items in the collages are shoppable.
# - Users can share their collages on social media platforms like Pinterest and Instagram, targeting the Gen Z demographic.
# - The announcement follows a report of a 34.7% year-over-year increase in Depop's Gross Merchandise Sales, positioning it for a $1 billion GMS run rate.
# - Rival Mercari reported a Gross Merchandise Value of $728 million for Q4 2024. [Bullish]
#
# --- Article 10 ---
# Title: Google’s cheaper AI Plus plan is now available in over 40 countries
# Summary: - Google has launched its AI Plus plan in over 40 countries, including locations in Africa, Asia, and Latin America.
# - The plan, initially introduced in Indonesia for Rp 75,000 ($4.50), is priced around $5 in most countries, with a 50% discount for six months in select locations like Nepal and Mexico.
# - The Plus tier provides access to Gemini 2.5 Pro, image and video creation tools, enhanced features in NotebookLM, and 200GB of cloud storage.
# - This launch follows OpenAI's introduction of its sub-$5 ChatGPT Go plan in Indonesia, although India is not included in Google's rollout.
# - Both Google and OpenAI are targeting markets with lower-cost subscription options to attract more users. [Bullish]
#
# --- Article 11 ---
# Title: South Korea’s ‘Silicon Valley’ struggles to live up to its global ambitions
# Summary: - Pangyo Techno Valley (PTV), located near Seoul, is home to over 1,800 startups and major tech firms like Naver and Kakao, but faces skepticism about its comparison to Silicon Valley.
# - Approximately 91.5% of companies in PTV are small and mid-sized businesses, with only 3.6% being large tech firms, indicating a lack of dominance in the tech landscape.
# - Many startups are relocating back to Gangnam due to better access to talent and venture capital, highlighting a shift in the tech ecosystem.
# - Challenges for Korean startups include a small domestic market, weaker global investor connections, and difficulties in storytelling, which hinder their ability to compete internationally.
# - Despite these challenges, there is optimism about PTV's potential to expand into AI, biotech, and deep tech, with ongoing government support for startup growth. [Cautious]
#
# --- Article 12 ---
# Title: How Al Gore used AI to track 660M polluters
# Summary: - Al Gore's nonprofit Climate Trace launched a tool that uses AI to track fine particulate pollution from over 660 million sources globally.
# - The tool provides access to raw data and visualizations of PM2.5 pollution, helping people understand its origins and impact on public health.
# - Climate Trace's initiative was inspired by local efforts in Memphis to block a crude oil pipeline, highlighting the need for precise pollution tracking.
# - Recent research has revealed that fine particulate pollution is linked to various health issues, including lung cancer, heart disease, and other serious ailments.
# - Gore believes increased awareness of fossil fuel health effects could accelerate the transition to cleaner technologies and garner political support for reducing emissions. [Bullish]
#
# --- Article 13 ---
# Title: Where has Final Fantasy Tactics been all my life?
# Summary: - Final Fantasy Tactics: The Ivalice Chronicles is a remaster of the strategy RPG, praised for its mature storytelling and nostalgic elements.
# - Players assume the role of Ramza Beoulve, navigating a complex narrative filled with political intrigue and moral dilemmas.
# - The game features a customizable job system, allowing players to create unique character builds, enhancing the strategic gameplay experience.
# - Despite the enjoyment of character customization, the game requires significant grinding to unlock abilities, making it challenging to build a diverse team.
# - The remaster is set to launch on September 30th across multiple platforms, fulfilling a long-standing desire for a strategy RPG experience. [Bullish]
#
# --- Article 14 ---
# Title: Pokémon Legends Z-A is bringing fashion back to the franchise
# Summary: - Pokémon Legends: Z-A introduces extensive character customization options, marking a significant improvement over previous titles in the franchise.
# - The game is set in Lumiose, a city inspired by Paris, featuring a vibrant environment filled with fashion-conscious NPCs.
# - Players can customize their character's outfits extensively, including shoes, tops, and accessories, with options available regardless of gender.
# - In-game currency can be earned through battles, which can be spent on clothing and items to enhance the player's experience.
# - The game emphasizes personal expression through fashion, with various hairstyles, skin tones, and physical customization options available at the start. [Bullish]
#
# --- Article 15 ---
# Title: Lucid kicks off its Nuro-Uber robotaxi deal with delivery of first vehicle
# Summary: - Lucid has delivered the first Gravity SUV to Nuro for retrofitting as part of a robotaxi deal with Uber, aiming to deploy 20,000 autonomous vehicles in the US over the next six years.
# - The vehicle was built in Casa Grande, Arizona, and retrofitting with autonomous driving hardware is taking place at Lucid’s headquarters in Newark, California.
# - The prototype is now at Nuro’s Santa Clara facility for software integration and testing, with plans to deploy the first road-ready robotaxi on Uber’s network next year.
# - Despite this milestone, the companies face challenges ahead, as many autonomous vehicle developers have struggled to deliver significant numbers of self-driving cars.
# - Current examples of operational autonomous vehicles include Waymo's fewer than 2,000 vehicles and Tesla's limited robotaxi presence in Austin, Texas. [Cautious]
#
# --- Article 16 ---
# Title: Trump’s H-1B chaos is Europe&#8217;s opportunity to steal tech talent
# Summary: - The US tech industry is reacting to a new $100,000 fee on H-1B visas, which has caused uncertainty for skilled foreign workers.
# - European tech startups are actively seeking to attract disillusioned foreign workers affected by the visa changes, with many companies offering competitive salaries and visa sponsorship.
# - Founders from various UK-based tech firms are publicly promoting job opportunities, emphasizing less uncertainty compared to the US.
# - The British government is reportedly considering eliminating visa charges for top global talent in response to the H-1B chaos.
# - US companies, particularly startups, are concerned about the negative impact of the new policy, with some executives suggesting it could benefit overseas tech hubs. [Cautious]
#
# --- Article 17 ---
# Title: A Bluesky server issue froze some users&#8217; feeds this morning
# Summary: - Bluesky experienced a network disruption this morning, causing some users' feeds to freeze and not update for hours.
# - The service page initially did not report an outage but later acknowledged the "network disruption" that delayed posts for several hours.
# - Some users were able to post successfully, but encountered issues accessing their posts, which displayed incorrect timestamps.
# - While some users faced significant issues, others reported that their feeds were functioning normally throughout the incident.
# - As of September 24th, Bluesky appears to be mostly back to normal. [Neutral]
#
# --- Article 18 ---
# Title: Pocket Casts is showing ads to people who paid for an ad-free app
# Summary: - Pocket Casts is facing criticism for displaying ads to legacy users who were promised an ad-free experience.
# - CEO Matt Mullenweg stated that the ads appearing for lifetime members are due to a bug, which will be fixed.
# - Pocket Casts originally launched as a paid app in 2010, later transitioning to a subscription model and offering free lifetime access to early purchasers.
# - The app was acquired by Automattic in 2021, and lifetime memberships were rebranded as “Pocket Casts Champion” in August 2024, with no mention of ads in the rebranding announcement.
# - A Pocket Casts employee indicated that ads were introduced to support app maintenance, contradicting Mullenweg's assertion that it is a bug. [Cautious]

# %%
async def critic_node(state: AgentState) -> AgentState:
    """Risk & Grounding Critic: flags rumor/risk and checks extractiveness."""
    async def critique(a: Article):
        if not a.get("summary"):
            a["risk"] = "no-summary"
            a["grounded"] = False
            return a
        prompt = f"""You are a Risk & Grounding Critic for financial/tech news.
Given the article text and its 3–5 bullet summary, do two things:

1) Is each bullet extractive (appears in the text) and free of speculation? Reply "YES" only if all bullets are extractive; else "NO".
2) Provide a short risk note: one of ["rumor-risk","low-evidence","balanced","well-sourced"].

Return strict JSON with keys: grounded (true/false), risk (string), issues (array of bullet indices with problems).

TITLE: {a['title']}
TEXT:
{a['text'][:6000]}
SUMMARY:
{a['summary']}"""
        rsp = oai.chat.completions.create(
            model=OPENAI_MODEL,
            messages=[{"role":"user","content":prompt}],
            temperature=0,
            response_format={"type":"json_object"}
        )
        data = json.loads(rsp.choices[0].message.content)
        a["grounded"] = bool(data.get("grounded", False))
        a["risk"] = str(data.get("risk", "balanced"))
        # Optionally: you could redact problematic bullets here
        return a
    state["articles"] = await asyncio.gather(*(critique(a) for a in state["articles"]))
    return state

# %%
state = arun(mod.critic_node(state))
print("After critic:", sum(1 for a in state["articles"] if a.get("grounded") is not None))
print(state["articles"][0]["grounded"], state["articles"][0].get("risk"))
# Out:
# After critic: 18
# True well-sourced

# %%
for i, art in enumerate(state["articles"], 1):
    print(f"\n--- Article {i} ---")
    print("Title:", art["title"])
    print("Summary:", art["summary"])
    print("Grounded:", art.get("grounded"))
    print("Risk:", art.get("risk"))
    print("Issues:", art.get("issues", []))
# Out:
# --- Article 1 ---
# Title: Strengthening our Frontier Safety Framework
# Summary: - The latest update to the Frontier Safety Framework (FSF) focuses on identifying and mitigating severe risks from advanced AI models, building on previous iterations and collaborations with experts.
# - A new Critical Capability Level (CCL) has been introduced to address risks associated with harmful manipulation by AI models that could significantly alter beliefs and behaviors.
# - The Framework has been expanded to include protocols for misalignment risks, ensuring that AI models do not interfere with operators' control over their operations.
# - The risk assessment process has been sharpened to prioritize critical threats, with detailed analyses conducted before external launches and large-scale internal deployments.
# - The update reflects a commitment to an evidence-based approach in tracking AI risks, aiming to ensure that AI advancements benefit humanity while minimizing potential harms. [Bullish]
# Grounded: True
# Risk: well-sourced
# Issues: []
#
# --- Article 2 ---
# Title: Discovering new solutions to century-old problems in fluid dynamics
# Summary: - A new method leveraging AI techniques has been developed to address long-standing challenges in fluid dynamics, mathematics, and physics.
# - The research introduces a novel family of unstable singularities in complex fluid equations, contributing to the understanding of foundational questions in fluid dynamics.
# - The study utilized Physics-Informed Neural Networks (PINNs) to achieve unprecedented accuracy in discovering these singularities, refining predictions to a high degree of precision.
# - This breakthrough is expected to usher in a new era of computer-assisted mathematics, combining deep mathematical insights with advanced AI methodologies.
# [Bullish]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 3 ---
# Title: Gemini achieves gold-level performance at the International Collegiate Programming Contest World Finals
# Summary: - Gemini 2.5 Deep Think achieved gold-medal level performance at the 2025 International Collegiate Programming Contest (ICPC) World Finals, solving 10 out of 12 problems.
# - This performance follows its previous gold-medal win at the International Mathematical Olympiad (IMO) two months prior.
# - The ICPC is recognized as the oldest and most prestigious algorithmic programming competition at the college level, with participants from nearly 3000 universities across over 103 countries.
# - Gemini solved a unique problem (Problem C) that no university team managed to solve, showcasing its advanced problem-solving capabilities.
# - The achievement highlights the potential for AI to serve as a collaborative tool in software development and complex problem-solving across various fields. [Bullish]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 4 ---
# Title: Using AI to perceive the universe in greater depth
# Summary: - The Deep Loop Shaping method enhances control of gravitational wave observatories, aiding astronomers in understanding the universe's dynamics and formation.
# - This AI technique reduces noise and improves stability in LIGO's feedback system, allowing for more accurate measurements of gravitational waves.
# - Deep Loop Shaping has demonstrated a noise reduction of 30 to 100 times, potentially enabling astronomers to detect hundreds more gravitational wave events annually.
# - The method has been successfully tested on LIGO's hardware, showing strong performance in both simulations and real-world applications.
# - Future applications of Deep Loop Shaping may extend beyond gravitational wave observatories to fields like aerospace, robotics, and structural engineering. [Bullish]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 5 ---
# Title: Image editing in Gemini just got a major upgrade
# Summary: - Google DeepMind has launched a new image editing model integrated into the Gemini app, which is now the top-rated image editing model globally.
# - The update focuses on maintaining character likeness in edited images, ensuring that people and pets look consistently like themselves across different edits.
# - Users can upload photos and make various changes, such as costume or location alterations, blending multiple images, and applying styles from one image to another.
# - The Gemini app allows for multi-turn editing, enabling users to make iterative changes while preserving other parts of the image.
# - All images created or edited in the Gemini app will feature a visible watermark and an invisible SynthID digital watermark to indicate they are AI-generated. [Bullish]
# Grounded: False
# Risk: well-sourced
# Issues: []
#
# --- Article 6 ---
# Title: Introducing Gemma 3 270M: The compact model for hyper-efficient AI
# Summary: - The Gemma family of open models has recently expanded with the introduction of Gemma 3 270M, a compact model featuring 270 million parameters designed for task-specific fine-tuning.
# - Gemma 3 270M is engineered for efficiency, allowing developers to create lean and cost-effective production systems that excel in tasks like text classification and data extraction.
# - The model builds on the success of previous Gemma models, demonstrating its capabilities through real-world applications, such as Adaptive ML's collaboration with SK Telecom for multilingual content moderation.
# - Gemma 3 270M is designed to facilitate the creation of specialized models, empowering developers to innovate and customize AI solutions easily.
# - The Gemmaverse continues to grow, with downloads surpassing 200 million, highlighting the community's engagement and the potential for further innovation. [Bullish]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 7 ---
# Title: UK police arrest man linked to ransomware attack that caused airport disruptions in Europe
# Summary: - A man in his forties was arrested by the U.K.’s National Crime Agency (NCA) in connection with a ransomware attack affecting several European airports.
# - The attack targeted check-in systems from Collins Aerospace, causing delays at Brussels, Berlin, Dublin, and London’s Heathrow airport.
# - The disruptions began on Friday and continued until Tuesday, when the man was arrested in West Sussex.
# - The arrested individual has been released on conditional bail, and the investigation is still in its early stages. [Cautious]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 8 ---
# Title: Alibaba to offer Nvidia’s physical AI development tools in its AI platform
# Summary: - Nvidia has partnered with Alibaba to integrate its AI development tools into Alibaba's Cloud Platform for AI, focusing on robotics, self-driving cars, and connected spaces.
# - The collaboration includes Nvidia’s Physical AI software stack, which creates 3D replicas of real-world environments for training AI models.
# - Alibaba is increasing its AI investment beyond a previously set budget of $50 billion and plans to launch new data centers in Brazil, France, and the Netherlands.
# - The company also introduced Qwen 3-Max, its largest language model to date, trained on 1 trillion parameters, aimed at coding and agentic applications.
# [Bullish]
# Grounded: True
# Risk: well-sourced
# Issues: []
#
# --- Article 9 ---
# Title: Depop launches a fashion collaging tool to style Pinterest-worthy outfits
# Summary: - Depop has launched a new styling and collaging tool called “Outfits,” aimed at users who enjoy creating fashion collages.
# - The feature allows users to design outfits with customization options, including backgrounds and templates, and all items in the collages are shoppable.
# - Users can share their collages on social media platforms like Pinterest and Instagram, targeting the Gen Z demographic.
# - The announcement follows a report of a 34.7% year-over-year increase in Depop's Gross Merchandise Sales, positioning it for a $1 billion GMS run rate.
# - Rival Mercari reported a Gross Merchandise Value of $728 million for Q4 2024. [Bullish]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 10 ---
# Title: Google’s cheaper AI Plus plan is now available in over 40 countries
# Summary: - Google has launched its AI Plus plan in over 40 countries, including locations in Africa, Asia, and Latin America.
# - The plan, initially introduced in Indonesia for Rp 75,000 ($4.50), is priced around $5 in most countries, with a 50% discount for six months in select locations like Nepal and Mexico.
# - The Plus tier provides access to Gemini 2.5 Pro, image and video creation tools, enhanced features in NotebookLM, and 200GB of cloud storage.
# - This launch follows OpenAI's introduction of its sub-$5 ChatGPT Go plan in Indonesia, although India is not included in Google's rollout.
# - Both Google and OpenAI are targeting markets with lower-cost subscription options to attract more users. [Bullish]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 11 ---
# Title: South Korea’s ‘Silicon Valley’ struggles to live up to its global ambitions
# Summary: - Pangyo Techno Valley (PTV), located near Seoul, is home to over 1,800 startups and major tech firms like Naver and Kakao, but faces skepticism about its comparison to Silicon Valley.
# - Approximately 91.5% of companies in PTV are small and mid-sized businesses, with only 3.6% being large tech firms, indicating a lack of dominance in the tech landscape.
# - Many startups are relocating back to Gangnam due to better access to talent and venture capital, highlighting a shift in the tech ecosystem.
# - Challenges for Korean startups include a small domestic market, weaker global investor connections, and difficulties in storytelling, which hinder their ability to compete internationally.
# - Despite these challenges, there is optimism about PTV's potential to expand into AI, biotech, and deep tech, with ongoing government support for startup growth. [Cautious]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 12 ---
# Title: How Al Gore used AI to track 660M polluters
# Summary: - Al Gore's nonprofit Climate Trace launched a tool that uses AI to track fine particulate pollution from over 660 million sources globally.
# - The tool provides access to raw data and visualizations of PM2.5 pollution, helping people understand its origins and impact on public health.
# - Climate Trace's initiative was inspired by local efforts in Memphis to block a crude oil pipeline, highlighting the need for precise pollution tracking.
# - Recent research has revealed that fine particulate pollution is linked to various health issues, including lung cancer, heart disease, and other serious ailments.
# - Gore believes increased awareness of fossil fuel health effects could accelerate the transition to cleaner technologies and garner political support for reducing emissions. [Bullish]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 13 ---
# Title: Where has Final Fantasy Tactics been all my life?
# Summary: - Final Fantasy Tactics: The Ivalice Chronicles is a remaster of the strategy RPG, praised for its mature storytelling and nostalgic elements.
# - Players assume the role of Ramza Beoulve, navigating a complex narrative filled with political intrigue and moral dilemmas.
# - The game features a customizable job system, allowing players to create unique character builds, enhancing the strategic gameplay experience.
# - Despite the enjoyment of character customization, the game requires significant grinding to unlock abilities, making it challenging to build a diverse team.
# - The remaster is set to launch on September 30th across multiple platforms, fulfilling a long-standing desire for a strategy RPG experience. [Bullish]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 14 ---
# Title: Pokémon Legends Z-A is bringing fashion back to the franchise
# Summary: - Pokémon Legends: Z-A introduces extensive character customization options, marking a significant improvement over previous titles in the franchise.
# - The game is set in Lumiose, a city inspired by Paris, featuring a vibrant environment filled with fashion-conscious NPCs.
# - Players can customize their character's outfits extensively, including shoes, tops, and accessories, with options available regardless of gender.
# - In-game currency can be earned through battles, which can be spent on clothing and items to enhance the player's experience.
# - The game emphasizes personal expression through fashion, with various hairstyles, skin tones, and physical customization options available at the start. [Bullish]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 15 ---
# Title: Lucid kicks off its Nuro-Uber robotaxi deal with delivery of first vehicle
# Summary: - Lucid has delivered the first Gravity SUV to Nuro for retrofitting as part of a robotaxi deal with Uber, aiming to deploy 20,000 autonomous vehicles in the US over the next six years.
# - The vehicle was built in Casa Grande, Arizona, and retrofitting with autonomous driving hardware is taking place at Lucid’s headquarters in Newark, California.
# - The prototype is now at Nuro’s Santa Clara facility for software integration and testing, with plans to deploy the first road-ready robotaxi on Uber’s network next year.
# - Despite this milestone, the companies face challenges ahead, as many autonomous vehicle developers have struggled to deliver significant numbers of self-driving cars.
# - Current examples of operational autonomous vehicles include Waymo's fewer than 2,000 vehicles and Tesla's limited robotaxi presence in Austin, Texas. [Cautious]
# Grounded: False
# Risk: balanced
# Issues: []
#
# --- Article 16 ---
# Title: Trump’s H-1B chaos is Europe&#8217;s opportunity to steal tech talent
# Summary: - The US tech industry is reacting to a new $100,000 fee on H-1B visas, which has caused uncertainty for skilled foreign workers.
# - European tech startups are actively seeking to attract disillusioned foreign workers affected by the visa changes, with many companies offering competitive salaries and visa sponsorship.
# - Founders from various UK-based tech firms are publicly promoting job opportunities, emphasizing less uncertainty compared to the US.
# - The British government is reportedly considering eliminating visa charges for top global talent in response to the H-1B chaos.
# - US companies, particularly startups, are concerned about the negative impact of the new policy, with some executives suggesting it could benefit overseas tech hubs. [Cautious]
# Grounded: False
# Risk: low-evidence
# Issues: []
#
# --- Article 17 ---
# Title: A Bluesky server issue froze some users&#8217; feeds this morning
# Summary: - Bluesky experienced a network disruption this morning, causing some users' feeds to freeze and not update for hours.
# - The service page initially did not report an outage but later acknowledged the "network disruption" that delayed posts for several hours.
# - Some users were able to post successfully, but encountered issues accessing their posts, which displayed incorrect timestamps.
# - While some users faced significant issues, others reported that their feeds were functioning normally throughout the incident.
# - As of September 24th, Bluesky appears to be mostly back to normal. [Neutral]
# Grounded: False
# Risk: balanced
# Issues: []
#
# --- Article 18 ---
# Title: Pocket Casts is showing ads to people who paid for an ad-free app
# Summary: - Pocket Casts is facing criticism for displaying ads to legacy users who were promised an ad-free experience.
# - CEO Matt Mullenweg stated that the ads appearing for lifetime members are due to a bug, which will be fixed.
# - Pocket Casts originally launched as a paid app in 2010, later transitioning to a subscription model and offering free lifetime access to early purchasers.
# - The app was acquired by Automattic in 2021, and lifetime memberships were rebranded as “Pocket Casts Champion” in August 2024, with no mention of ads in the rebranding announcement.
# - A Pocket Casts employee indicated that ads were introduced to support app maintenance, contradicting Mullenweg's assertion that it is a bug. [Cautious]
# Grounded: False
# Risk: low-evidence
# Issues: []

# %%
async def tagger_node(state: AgentState) -> AgentState:
    """Entity & Topic Tagger: companies, people, tickers, topics."""
    async def tag(a: Article):
        if not a.get("text"):
            return a
        prompt = f"""Extract entities and topics as JSON with keys:
companies (array), people (array), tickers (array), topics (array: e.g., 'chips','LLMs','rates').
Base only on the TEXT below. No guessing.

TEXT:
{a['text'][:6000]}"""
        rsp = oai.chat.completions.create(
            model=OPENAI_MODEL,
            messages=[{"role":"user","content":prompt}],
            temperature=0,
            response_format={"type":"json_object"}
        )
        a["entities"] = json.loads(rsp.choices[0].message.content)
        return a
    state["articles"] = await asyncio.gather(*(tag(a) for a in state["articles"]))
    return state

# %%
state = arun(mod.tagger_node(state))
print("After tagger: entities =", sum(1 for a in state["articles"] if a.get("entities")))
print(state["articles"][0]["entities"])
# Out:
# After tagger: entities = 18
# {'companies': [], 'people': [], 'tickers': [], 'topics': ['AI', 'risk assessment', 'safety', 'machine learning', 'AGI']}

# %%
for i, art in enumerate(state["articles"], 1):
    print(f"\n--- Article {i} ---")
    print("Title:", art.get("title"))
    entities = art.get("entities", {})
    print("Companies:", entities.get("companies", []))
    print("People:", entities.get("people", []))
    print("Tickers:", entities.get("tickers", []))
    print("Topics:", entities.get("topics", []))
# Out:
# --- Article 1 ---
# Title: Strengthening our Frontier Safety Framework
# Companies: []
# People: []
# Tickers: []
# Topics: ['AI', 'risk assessment', 'safety', 'machine learning', 'AGI']
#
# --- Article 2 ---
# Title: Discovering new solutions to century-old problems in fluid dynamics
# Companies: []
# People: ['Yongji Wang', 'Mehdi Bennani', 'James Martens', 'Sébastien Racanière', 'Sam Blackwell', 'Alex Matthews', 'Stanislav Nikolov', 'Gonzalo Cao-Labora', 'Daniel S. Park', 'Martin Arjovsky', 'Daniel Worrall', 'Chongli Qin', 'Ferran Alet', 'Borislav Kozlovskii', 'Nenad Tomašev', 'Alex Davies', 'Pushmeet Kohli', 'Tristan Buckmaster', 'Bogdan Georgiev', 'Javier Gómez-Serrano', 'Ray Jiang', 'Ching-Yao Lai']
# Tickers: []
# Topics: ['fluid dynamics', 'AI', 'mathematics', 'physics', 'engineering', 'singularities', 'machine learning', 'Physics-Informed Neural Networks', 'computer-assisted proofs']
#
# --- Article 3 ---
# Title: Gemini achieves gold-level performance at the International Collegiate Programming Contest World Finals
# Companies: ['Google DeepMind']
# People: ['Dr. Bill Poucher']
# Tickers: []
# Topics: ['AI', 'programming', 'ICPC', 'algorithmic problem solving', 'reinforcement learning']
#
# --- Article 4 ---
# Title: Using AI to perceive the universe in greater depth
# Companies: ['Caltech', 'GSSI']
# People: ['Albert Einstein']
# Tickers: []
# Topics: ['gravitational waves', 'AI', 'control systems', 'LIGO', 'physics', 'cosmology', 'vibration suppression', 'noise cancellation']
#
# --- Article 5 ---
# Title: Image editing in Gemini just got a major upgrade
# Companies: ['Google DeepMind']
# People: []
# Tickers: []
# Topics: ['image editing', 'AI']
#
# --- Article 6 ---
# Title: Introducing Gemma 3 270M: The compact model for hyper-efficient AI
# Companies: ['Adaptive ML', 'SK Telecom']
# People: []
# Tickers: []
# Topics: ['AI', 'fine-tuning', 'multimodal', 'model specialization']
#
# --- Article 7 ---
# Title: UK police arrest man linked to ransomware attack that caused airport disruptions in Europe
# Companies: ['Collins Aerospace', 'TechCrunch']
# People: ['Paul Foster', 'Richard Crowe']
# Tickers: []
# Topics: ['ransomware', 'cyber crime']
#
# --- Article 8 ---
# Title: Alibaba to offer Nvidia’s physical AI development tools in its AI platform
# Companies: ['Nvidia', 'Intel', 'OpenAI', 'Alibaba']
# People: []
# Tickers: []
# Topics: ['AI', 'cloud services', 'chips', 'large language models', 'data centers']
#
# --- Article 9 ---
# Title: Depop launches a fashion collaging tool to style Pinterest-worthy outfits
# Companies: ['Depop', 'Etsy', 'Pinterest', 'Box', 'a16z', 'ElevenLabs', 'Wayve', 'Sequoia Capital', 'Mercari']
# People: ['Elad Gil']
# Tickers: []
# Topics: ['fashion', 'resale', 'collages', 'Gen Z', 'ecommerce']
#
# --- Article 10 ---
# Title: Google’s cheaper AI Plus plan is now available in over 40 countries
# Companies: ['Google', 'OpenAI']
# People: []
# Tickers: []
# Topics: ['AI', 'subscription plans', 'cloud storage']
#
# --- Article 11 ---
# Title: South Korea’s ‘Silicon Valley’ struggles to live up to its global ambitions
# Companies: ['Naver', 'Kakao', 'Nexon', 'NCSoft', 'HD Hyundai', 'AhnLab', 'Samsung Electronics', 'SK Hynix', '42dot', 'Portologics', 'Z Venture Capital', 'Netflix', 'Box', 'a16z', 'ElevenLabs', 'Wayve', 'Sequoia Capital', 'Elad Gil', 'TechCrunch', 'Kakao Ventures']
# People: ['Hyoungchul Choi', 'Janice Sa']
# Tickers: []
# Topics: ['startups', 'AI', 'gaming', 'fintech', 'venture capital']
#
# --- Article 12 ---
# Title: How Al Gore used AI to track 660M polluters
# Companies: ['Climate Trace', 'Netflix', 'Box', 'a16z', 'ElevenLabs', 'Wayve', 'Sequoia Capital', 'Carnegie Mellon University']
# People: ['Al Gore', 'Joel Schwartz']
# Tickers: []
# Topics: ['pollution', 'AI', 'public health', 'PM2.5', 'fossil fuels', 'greenhouse gas emissions', 'health effects']
#
# --- Article 13 ---
# Title: Where has Final Fantasy Tactics been all my life?
# Companies: ['Square Enix']
# People: ['Ramza Beoulve', 'Mustadio Bunansa', 'Ffamran Balthier Bunansa', 'Hitoshi Sakimoto']
# Tickers: []
# Topics: ['RPG', 'strategy games', 'Final Fantasy', 'Ivalice']
#
# --- Article 14 ---
# Title: Pokémon Legends Z-A is bringing fashion back to the franchise
# Companies: ['Nintendo', 'Game Freak']
# People: []
# Tickers: []
# Topics: ['Pokémon', 'character customization', 'gaming', 'fashion']
#
# --- Article 15 ---
# Title: Lucid kicks off its Nuro-Uber robotaxi deal with delivery of first vehicle
# Companies: ['Lucid', 'Uber', 'Nuro', 'Waymo', 'Tesla']
# People: []
# Tickers: []
# Topics: ['robotaxi', 'autonomous vehicles', 'self-driving cars']
#
# --- Article 16 ---
# Title: Trump’s H-1B chaos is Europe&#8217;s opportunity to steal tech talent
# Companies: ['Amazon', 'Google', 'Microsoft', 'Cleo', 'Synthesia', 'Wordsmith', 'Definely', 'Exo Labs', 'Verto', 'Y Combinator']
# People: ['Donald Trump', 'Barney Hussey-Yeo', 'Victor Riparbelli', 'Ross McNairn', 'Garry Tan']
# Tickers: []
# Topics: ['H-1B visas', 'tech talent', 'immigration', 'AI', 'startups', 'visa changes']
#
# --- Article 17 ---
# Title: A Bluesky server issue froze some users&#8217; feeds this morning
# Companies: ['Bluesky', 'Verge', 'Reddit']
# People: []
# Tickers: []
# Topics: ['network disruption', 'social media']
#
# --- Article 18 ---
# Title: Pocket Casts is showing ads to people who paid for an ad-free app
# Companies: ['Pocket Casts', 'Automattic']
# People: ['Matt Mullenweg']
# Tickers: []
# Topics: ['ads', 'subscriptions', 'lifetime memberships', 'premium services']

# %%
def curator_node(state: AgentState) -> AgentState:
    # Prioritise grounded items; then keyword score; keep category balance.
    state["articles"].sort(key=lambda a: (1 if a.get("grounded") else 0, a.get("score", 0.0)), reverse=True)
    per_cat_limit = max(1, state["top_n"] // 3)
    kept, counts = [], {"AI":0, "Tech":0, "Finance":0}
    for a in state["articles"]:
        if counts[a["category"]] < per_cat_limit:
            kept.append(a)
            counts[a["category"]] += 1
        if len(kept) >= state["top_n"]:
            break
    if len(kept) < state["top_n"]:
        chosen = set(id(x) for x in kept)
        for a in state["articles"]:
            if id(a) in chosen:
                continue
            kept.append(a)
            if len(kept) >= state["top_n"]:
                break
    state["articles"] = kept
    return state

# %%
state = mod.curator_node(state)
print("After curator:", len(state["articles"]))
# Out:
# After curator: 9

# %%
for i, a in enumerate(state["articles"], 1):
    print(f"\n--- Curated {i} ---")
    print("Title:", a.get("title"))
    print("Category:", a.get("category"))
    print("Grounded:", a.get("grounded"))
    print("Risk:", a.get("risk"))
    print("Score:", round(a.get("score", 0.0), 3))
# Out:
# --- Curated 1 ---
# Title: Alibaba to offer Nvidia’s physical AI development tools in its AI platform
# Category: Tech
# Grounded: True
# Risk: well-sourced
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 7
#       5 print("Grounded:", a.get("grounded"))
#       6 print("Risk:", a.get("risk"))
# ----> 7 print("Score:", round(a.get("score", 0.0), 3))
#
# TypeError: type tuple doesn't define __round__ method

# %%
def formatter_node(state: AgentState) -> AgentState:
    today = datetime.date.today().isoformat()
    lines = [f"# Daily AI • Tech • Finance — {today}", ""]
    for cat in ["AI", "Tech", "Finance"]:
        section = [a for a in state["articles"] if a["category"] == cat]
        if not section:
            continue
        lines.append(f"## {cat}")
        for a in section:
            risk = a.get("risk", "balanced")
            grounded = "Grounded✅" if a.get("grounded") else "Needs-check⚠️"
            lines.append(f"### [{a['title']}]({a['link']})  \n*{grounded} • risk={risk}*")
            lines.append(a.get("summary") or "(no summary)")
            ents = a.get("entities") or {}
            if ents:
                lines.append(f"_Entities:_ {ents.get('companies', [])}  \n_Tickers:_ {ents.get('tickers', [])}  \n_Topics:_ {ents.get('topics', [])}")
            lines.append("")
    state["digest_md"] = "\n".join(lines)
    return state

# %%
state = mod.formatter_node(state)
print("=== Digest Output ===\n")
print(state["digest_md"])
# Out:
# === Digest Output ===
#
# # Daily AI • Tech • Finance — 2025-09-24
#
# ## AI
# ### [Strengthening our Frontier Safety Framework](https://deepmind.google/discover/blog/strengthening-our-frontier-safety-framework/)
# *Grounded✅ • risk=well-sourced*
# - The latest update to the Frontier Safety Framework (FSF) focuses on identifying and mitigating severe risks from advanced AI models, building on previous iterations and collaborations with experts.
# - A new Critical Capability Level (CCL) has been introduced to address risks associated with harmful manipulation by AI models that could significantly alter beliefs and behaviors.
# - The Framework has been expanded to include protocols for misalignment risks, ensuring that AI models do not interfere with operators' control over their operations.
# - The risk assessment process has been sharpened to prioritize critical threats, with detailed analyses conducted before external launches and large-scale internal deployments.
# - The update reflects a commitment to an evidence-based approach in tracking AI risks, aiming to ensure that AI advancements benefit humanity while minimizing potential harms. [Bullish]
# _Entities:_ []
# _Tickers:_ []
# _Topics:_ ['AI', 'risk assessment', 'safety', 'machine learning', 'AGI']
#
# ### [Image editing in Gemini just got a major upgrade](https://deepmind.google/discover/blog/image-editing-in-gemini-just-got-a-major-upgrade/)
# *Needs-check⚠️ • risk=well-sourced*
# - Google DeepMind has launched a new image editing model integrated into the Gemini app, which is now the top-rated image editing model globally.
# - The update focuses on maintaining character likeness in edited images, ensuring that people and pets look consistently like themselves across different edits.
# - Users can upload photos and make various changes, such as costume or location alterations, blending multiple images, and applying styles from one image to another.
# - The Gemini app allows for multi-turn editing, enabling users to make iterative changes while preserving other parts of the image.
# - All images created or edited in the Gemini app will feature a visible watermark and an invisible SynthID digital watermark to indicate they are AI-generated. [Bullish]
# _Entities:_ ['Google DeepMind']
# _Tickers:_ []
# _Topics:_ ['image editing', 'AI']
#
# ### [Using AI to perceive the universe in greater depth](https://deepmind.google/discover/blog/using-ai-to-perceive-the-universe-in-greater-depth/)
# *Needs-check⚠️ • risk=low-evidence*
# - The Deep Loop Shaping method enhances control of gravitational wave observatories, aiding astronomers in understanding the universe's dynamics and formation.
# - This AI technique reduces noise and improves stability in LIGO's feedback system, allowing for more accurate measurements of gravitational waves.
# - Deep Loop Shaping has demonstrated a noise reduction of 30 to 100 times, potentially enabling astronomers to detect hundreds more gravitational wave events annually.
# - The method has been successfully tested on LIGO's hardware, showing strong performance in both simulations and real-world applications.
# - Future applications of Deep Loop Shaping may extend beyond gravitational wave observatories to fields like aerospace, robotics, and structural engineering. [Bullish]
# _Entities:_ ['Caltech', 'GSSI']
# _Tickers:_ []
# _Topics:_ ['gravitational waves', 'AI', 'control systems', 'LIGO', 'physics', 'cosmology', 'vibration suppression', 'noise cancellation']
#
# ## Tech
# ### [Alibaba to offer Nvidia’s physical AI development tools in its AI platform](https://techcrunch.com/2025/09/24/alibaba-to-offer-nvidias-physical-ai-development-tools-in-its-ai-platform/)
# *Grounded✅ • risk=well-sourced*
# - Nvidia has partnered with Alibaba to integrate its AI development tools into Alibaba's Cloud Platform for AI, focusing on robotics, self-driving cars, and connected spaces.
# - The collaboration includes Nvidia’s Physical AI software stack, which creates 3D replicas of real-world environments for training AI models.
# - Alibaba is increasing its AI investment beyond a previously set budget of $50 billion and plans to launch new data centers in Brazil, France, and the Netherlands.
# - The company also introduced Qwen 3-Max, its largest language model to date, trained on 1 trillion parameters, aimed at coding and agentic applications.
# [Bullish]
# _Entities:_ ['Nvidia', 'Intel', 'OpenAI', 'Alibaba']
# _Tickers:_ []
# _Topics:_ ['AI', 'cloud services', 'chips', 'large language models', 'data centers']
#
# ### [Trump’s H-1B chaos is Europe&#8217;s opportunity to steal tech talent](https://www.theverge.com/news/784412/trump-h-1b-visa-europe-steal)
# *Needs-check⚠️ • risk=low-evidence*
# - The US tech industry is reacting to a new $100,000 fee on H-1B visas, which has caused uncertainty for skilled foreign workers.
# - European tech startups are actively seeking to attract disillusioned foreign workers affected by the visa changes, with many companies offering competitive salaries and visa sponsorship.
# - Founders from various UK-based tech firms are publicly promoting job opportunities, emphasizing less uncertainty compared to the US.
# - The British government is reportedly considering eliminating visa charges for top global talent in response to the H-1B chaos.
# - US companies, particularly startups, are concerned about the negative impact of the new policy, with some executives suggesting it could benefit overseas tech hubs. [Cautious]
# _Entities:_ ['Amazon', 'Google', 'Microsoft', 'Cleo', 'Synthesia', 'Wordsmith', 'Definely', 'Exo Labs', 'Verto', 'Y Combinator']
# _Tickers:_ []
# _Topics:_ ['H-1B visas', 'tech talent', 'immigration', 'AI', 'startups', 'visa changes']
#
# ### [Google’s cheaper AI Plus plan is now available in over 40 countries](https://techcrunch.com/2025/09/24/googles-cheaper-ai-plus-plan-is-now-available-in-over-40-countries/)
# *Needs-check⚠️ • risk=low-evidence*
# - Google has launched its AI Plus plan in over 40 countries, including locations in Africa, Asia, and Latin America.
# - The plan, initially introduced in Indonesia for Rp 75,000 ($4.50), is priced around $5 in most countries, with a 50% discount for six months in select locations like Nepal and Mexico.
# - The Plus tier provides access to Gemini 2.5 Pro, image and video creation tools, enhanced features in NotebookLM, and 200GB of cloud storage.
# - This launch follows OpenAI's introduction of its sub-$5 ChatGPT Go plan in Indonesia, although India is not included in Google's rollout.
# - Both Google and OpenAI are targeting markets with lower-cost subscription options to attract more users. [Bullish]
# _Entities:_ ['Google', 'OpenAI']
# _Tickers:_ []
# _Topics:_ ['AI', 'subscription plans', 'cloud storage']
#
# ### [Where has Final Fantasy Tactics been all my life?](https://www.theverge.com/entertainment/783944/final-fantasy-tactics-remake-review-square-enix-playstation)
# *Needs-check⚠️ • risk=low-evidence*
# - Final Fantasy Tactics: The Ivalice Chronicles is a remaster of the strategy RPG, praised for its mature storytelling and nostalgic elements.
# - Players assume the role of Ramza Beoulve, navigating a complex narrative filled with political intrigue and moral dilemmas.
# - The game features a customizable job system, allowing players to create unique character builds, enhancing the strategic gameplay experience.
# - Despite the enjoyment of character customization, the game requires significant grinding to unlock abilities, making it challenging to build a diverse team.
# - The remaster is set to launch on September 30th across multiple platforms, fulfilling a long-standing desire for a strategy RPG experience. [Bullish]
# _Entities:_ ['Square Enix']
# _Tickers:_ []
# _Topics:_ ['RPG', 'strategy games', 'Final Fantasy', 'Ivalice']
#
# ### [UK police arrest man linked to ransomware attack that caused airport disruptions in Europe](https://techcrunch.com/2025/09/24/uk-police-arrest-man-linked-to-ransomware-attack-that-caused-airport-disruptions-in-europe/)
# *Needs-check⚠️ • risk=low-evidence*
# - A man in his forties was arrested by the U.K.’s National Crime Agency (NCA) in connection with a ransomware attack affecting several European airports.
# - The attack targeted check-in systems from Collins Aerospace, causing delays at Brussels, Berlin, Dublin, and London’s Heathrow airport.
# - The disruptions began on Friday and continued until Tuesday, when the man was arrested in West Sussex.
# - The arrested individual has been released on conditional bail, and the investigation is still in its early stages. [Cautious]
# _Entities:_ ['Collins Aerospace', 'TechCrunch']
# _Tickers:_ []
# _Topics:_ ['ransomware', 'cyber crime']
#
# ### [South Korea’s ‘Silicon Valley’ struggles to live up to its global ambitions](https://techcrunch.com/2025/09/24/south-koreas-silicon-valley-struggles-to-live-up-to-its-global-ambitions/)
# *Needs-check⚠️ • risk=low-evidence*
# - Pangyo Techno Valley (PTV), located near Seoul, is home to over 1,800 startups and major tech firms like Naver and Kakao, but faces skepticism about its comparison to Silicon Valley.
# - Approximately 91.5% of companies in PTV are small and mid-sized businesses, with only 3.6% being large tech firms, indicating a lack of dominance in the tech landscape.
# - Many startups are relocating back to Gangnam due to better access to talent and venture capital, highlighting a shift in the tech ecosystem.
# - Challenges for Korean startups include a small domestic market, weaker global investor connections, and difficulties in storytelling, which hinder their ability to compete internationally.
# - Despite these challenges, there is optimism about PTV's potential to expand into AI, biotech, and deep tech, with ongoing government support for startup growth. [Cautious]
# _Entities:_ ['Naver', 'Kakao', 'Nexon', 'NCSoft', 'HD Hyundai', 'AhnLab', 'Samsung Electronics', 'SK Hynix', '42dot', 'Portologics', 'Z Venture Capital', 'Netflix', 'Box', 'a16z', 'ElevenLabs', 'Wayve', 'Sequoia Capital', 'Elad Gil', 'TechCrunch', 'Kakao Ventures']
# _Tickers:_ []
# _Topics:_ ['startups', 'AI', 'gaming', 'fintech', 'venture capital']

# %%
from langgraph.graph import StateGraph, START, END   # make sure START, END are imported

graph = StateGraph(AgentState)

# Add your nodes
graph.add_node("fetcher", fetcher_node)
graph.add_node("curator", curator_node)
graph.add_node("critic", critic_node)
graph.add_node("formatter", formatter_node)

# Define the flow
graph.add_edge(START, "fetcher")       # entrypoint
graph.add_edge("fetcher", "curator")
graph.add_edge("curator", "critic")
graph.add_edge("critic", "formatter")
graph.add_edge("formatter", END)       # exit point

# Compile
app = graph.compile()

# %%
# run (async)
result = await app.ainvoke({
    "articles": [],
    "top_n": 10,          # ← add this
    # optionally other knobs you already use:
    # "keywords": ["CBA", "markets"],
    # "score_threshold": 0.6,
})

# %%
result
# Out:
# {'articles': [{'title': 'Strengthening our Frontier Safety Framework',
#    'link': 'https://deepmind.google/discover/blog/strengthening-our-frontier-safety-framework/',
#    'category': 'AI',
#    'text': "Responsibility & Safety\nStrengthening our Frontier Safety Framework\nWe’re expanding our risk domains and refining our risk assessment process.\nAI breakthroughs are transforming our everyday lives, from advancing mathematics, biology and astronomy to realizing the potential of personalized education. As we build increasingly powerful AI models, we’re committed to responsibly developing our technologies and taking an evidence-based approach to staying ahead of emerging risks.\nToday, we’re publishing the third iteration of our Frontier Safety Framework (FSF) — our most comprehensive approach yet to identifying and mitigating severe risks from advanced AI models.\nThis update builds upon our ongoing collaborations with experts across industry, academia and government. We’ve also incorporated lessons learned from implementing previous versions and evolving best practices in frontier AI safety.\nKey updates to the Framework\nAddressing the risks of harmful manipulation\nWith this update, we’re introducing a Critical Capability Level (CCL)* focused on harmful manipulation — specifically, AI models with powerful manipulative capabilities that could be misused to systematically and substantially change beliefs and behaviors in identified high stakes contexts over the course of interactions with the model, reasonably resulting in additional expected harm at severe scale.\nThis addition builds on and operationalizes research we’ve done to identify and evaluate mechanisms that drive manipulation from generative AI. Going forward, we'll continue to invest in this domain to better understand and measure the risks associated with harmful manipulation.\nAdapting our approach to misalignment risks\nWe’ve also expanded our Framework to address potential future scenarios where misaligned AI models might interfere with operators’ ability to direct, modify or shut down their operations.\nWhile our previous version of the Framework included an exploratory approach centered on instrumental reasoning CCLs (i.e., warning levels specific to when an AI model starts to think deceptively), with this update we now provide further protocols for our machine learning research and development CCLs focused on models that could accelerate AI research and development to potentially destabilizing levels.\nIn addition to the misuse risks arising from these capabilities, there are also misalignment risks stemming from a model’s potential for undirected action at these capability levels, and the likely integration of such models into AI development and deployment processes.\nTo address risks posed by CCLs, we conduct safety case reviews prior to external launches when relevant CCLs are reached. This involves performing detailed analyses demonstrating how risks have been reduced to manageable levels. For advanced machine learning research and development CCLs, large-scale internal deployments can also pose risk, so we are now expanding this approach to include such deployments.\nSharpening our risk assessment process\nOur Framework is designed to address risks in proportion to their severity. We’ve sharpened our CCL definitions specifically to identify the critical threats that warrant the most rigorous governance and mitigation strategies. We continue to apply safety and security mitigations before specific CCL thresholds are reached and as part of our standard model development approach.\nLastly, in this update, we go into more detail about our risk assessment process. Building on our core early-warning evaluations, we describe how we conduct holistic assessments that include systematic risk identification, comprehensive analyses of model capabilities and explicit determinations of risk acceptability.\nAdvancing our commitment to frontier safety\nThis latest update to our Frontier Safety Framework represents our continued commitment to taking a scientific and evidence-based approach to tracking and staying ahead of AI risks as capabilities advance to ...
#    'summary': None,
#    'score': 0.0,
#    'risk': 'no-summary',
#    'grounded': False},
#   {'title': 'UK police arrest man linked to ransomware attack that caused airport disruptions in Europe',
#    'link': 'https://techcrunch.com/2025/09/24/uk-police-arrest-man-linked-to-ransomware-attack-that-caused-airport-disruptions-in-europe/',
#    'category': 'Tech',
#    'text': 'The U.K.’s National Crime Agency (NCA) said on Wednesday that a man was arrested in connection to the ransomware attack that has caused delays and disruptions at several European airports since the weekend.\nThe hack targeted check-in systems provided by Collins Aerospace on Friday, causing delays at Brussels, Berlin, Dublin, and London’s Heathrow airport, which lasted until yesterday.\nWhile the NCA did not name the man, it said he is “in his forties” and that he was arrested in the southern county of West Sussex on Tuesday. The man has been released on conditional bail, the agency said.\n“Although this arrest is a positive step, the investigation into this incident is in its early stages and remains ongoing,” said Paul Foster, deputy director and head of the NCA’s National Cyber Crime Unit.\nNCA spokesperson Richard Crowe told TechCrunch that the agency had nothing else to add to the press release.',
#    'summary': None,
#    'score': 0.0,
#    'risk': 'no-summary',
#    'grounded': False},
#   {'title': 'Marvell Technology announces additional $5B stock repurchase authorization and $1B accelerated share repurchase program',
#    'link': 'https://seekingalpha.com/news/4498364-marvell-technology-announces-additional-5b-stock-repurchase-authorization-and-1b-accelerated-share-repurchase-program?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news',
#    'category': 'Finance',
#    'text': '- Marvell Technology (NASDAQ:MRVL) announced on Wednesday that its Board of Directors has authorized a new $5 billion stock repurchase program.\n- As of August 2, 2025, the company had approximately $2 billion remaining under its prior repurchase authorization. Since then, Marvell has repurchased $300 million of common',
#    'summary': None,
#    'score': 0.0,
#    'risk': 'no-summary',
#    'grounded': False},
#   {'title': 'Discovering new solutions to century-old problems in fluid dynamics',
#    'link': 'https://deepmind.google/discover/blog/discovering-new-solutions-to-century-old-problems-in-fluid-dynamics/',
#    'category': 'AI',
#    'text': "Science\nDiscovering new solutions to century-old problems in fluid dynamics\nOur new method could help mathematicians leverage AI techniques to tackle long-standing challenges in mathematics, physics and engineering.\nFor centuries, mathematicians have developed complex equations to describe the fundamental physics involved in fluid dynamics. These laws govern everything from the swirling vortex of a hurricane to airflow lifting an airplane’s wing.\nExperts can carefully craft scenarios that make theory go against practice, leading to situations which could never physically happen. These situations, such as when quantities like velocity or pressure become infinite, are called ‘singularities’ or ‘blow ups’. They help mathematicians identify fundamental limitations in the equations of fluid dynamics, and help improve our understanding of how the physical world functions.\nIn a new paper, we introduce an entirely new family of mathematical blow ups to some of the most complex equations that describe fluid motion. We’re publishing this work in collaboration with mathematicians and geophysicists from institutions including Brown University, New York University and Stanford University\nOur approach presents a new way to leverage AI techniques to tackle longstanding challenges in mathematics, physics and engineering that demand unprecedented accuracy and interpretability.\nThe importance of unstable singularities\nStability is a crucial aspect of singularity formation. A singularity is considered stable if it is robust to small changes. Conversely, an unstable singularity requires extremely precise conditions.\nIt’s expected that unstable singularities play a major role in foundational questions in fluid dynamics because mathematicians believe no stable singularities exist for the complex boundary-free 3D Euler and Navier-Stokes equations. Finding any singularity in the Navier-Stokes equations is one of the six famous Millennium Prize Problems that are still unsolved.\nWith our novel AI methods, we presented the first systematic discovery of new families of unstable singularities across three different fluid equations. We also observed a pattern emerging as the solutions become increasingly unstable. The number characterizing the speed of the blow up, lambda (λ), can be plotted against the order of instability, which is the number of unique ways the solution can deviate from the blow up. The pattern was visible in two of the equations studied, the Incompressible Porous Media (IPM) and Boussinesq equations. This suggests the existence of more unstable solutions, whose hypothesized lambda values lie along the same line.\nWe discovered these singularities by incorporating machine learning techniques such as second order optimizers for training neural networks. These methods allowed us to refine our accuracy to an unprecedented level. For reference, our largest errors addressed are equivalent to predicting the diameter of the Earth to within a few centimeters.\nHere we show an example of the vorticity (Ω) field found for one of the equations studied. This is a measure of how much the fluid is spinning at each point.\nWe also show a one-dimensional slice through the same field along an axis for all of the instabilities we discovered, showing the evolution of increasingly unstable singularities.\nNovel method navigates a vast landscape of singularities\nOur approach is based on the use of Physics-Informed Neural Networks (PINNs). Unlike conventional neural networks that learn from vast datasets, we trained our models to match equations which model the laws of physics. The network's output is constantly checked against what the physical equations expect, and it learns by minimizing its ‘residual’, the amount by which its solution fails to satisfy the equations.\nOur use of PINNs goes beyond their typical role as general-purpose tools used for solving partial differential equations (PDEs). By embedding mathematical insights dire ...
#    'summary': None,
#    'score': 0.0,
#    'risk': 'no-summary',
#    'grounded': False},
#   {'title': 'Alibaba to offer Nvidia’s physical AI development tools in its AI platform',
#    'link': 'https://techcrunch.com/2025/09/24/alibaba-to-offer-nvidias-physical-ai-development-tools-in-its-ai-platform/',
#    'category': 'Tech',
#    'text': 'Nvidia is on a dealmaking spree: Days after committing to taking a $5 billion stake in Intel and a whopping $100 billion investment in OpenAI, the GPU maker has now struck a partnership with China’s Alibaba.\nAlibaba said on Wednesday that it is integrating Nvidia’s AI development tools for robotics, self-driving cars, and connected spaces into its Cloud Platform for AI. The Chinese e-commerce giant will offer Nvidia’s Physical AI software stack, which can construct 3D replicas of real-world environments to generate synthetic data with which AI models can be trained for robotics, self-driving vehicles, or smart spaces like factories and warehouses.\nFinancial terms of the deal were not disclosed, but this marks a significant collaboration, as it brings together the world’s foremost developer of chips optimized for training AI models, and a major cloud services and AI model developer.\nThe deal comes as Alibaba focuses on building out its AI business further alongside its main e-commerce business. The company said on Wednesday that it is ramping up spending on AI tech past its previous $50 billion budget, and outlined plans to launch its first data centers in Brazil, France, and the Netherlands. It is also building more data centers in more countries, expanding its data center presence at 91 locations in 29 regions around the world.\nAlibaba on Wednesday also unveiled the latest iteration of its Qwen family of large language models, Qwen 3-Max. The company claims the model is its “largest and most capable model to date,” trained on 1 trillion parameters, and that it is well-suited for coding and agentic use.',
#    'summary': None,
#    'score': 0.0,
#    'risk': 'no-summary',
#    'grounded': False},
#   {'title': 'Borderlands 4 release delayed on Nintendo Switch 2',
#    'link': 'https://seekingalpha.com/news/4498340-borderlands-4-release-delayed-on-nintendo-switch-2?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news',
#    'category': 'Finance',
#    'text': 'The release of Borderlands 4 (NASDAQ:TTWO) game is being delayed on Switch 2 (OTCPK:NTDOF) (OTCPK:NTDOY) due to "additional development and polish time" required for the new Nintendo console, the official account of the video game posted on social\nThe release of Borderlands 4 (NASDAQ:TTWO) game is being delayed on Switch 2 (OTCPK:NTDOF) (OTCPK:NTDOY) due to "additional development and polish time" required for the new Nintendo console, the official account of the video game posted on social',
#    'summary': None,
#    'score': 0.0,
#    'risk': 'no-summary',
#    'grounded': False},
#   {'title': 'Gemini achieves gold-level performance at the International Collegiate Programming Contest World Finals',
#    'link': 'https://deepmind.google/discover/blog/gemini-achieves-gold-level-performance-at-the-international-collegiate-programming-contest-world-finals/',
#    'category': 'AI',
#    'text': 'Research\nGemini achieves gold-medal level at the International Collegiate Programming Contest World Finals\nGemini 2.5 Deep Think achieves breakthrough performance at the world’s most prestigious computer programming competition, demonstrating a profound leap in abstract problem solving.\nAn advanced version of Gemini 2.5 Deep Think has achieved gold-medal level performance at the 2025 International Collegiate Programming Contest (ICPC) World Finals.\nThis milestone builds directly on Gemini 2.5 Deep Think\'s gold-medal win at the International Mathematical Olympiad (IMO) just two months ago. Innovations from these efforts will continue to be integrated into future versions of Gemini Deep Think, expanding the frontier of advanced AI capabilities accessible to students and researchers.\nSolving complex tasks at these competitions requires deep abstract reasoning, creativity, the ability to synthesize novel solutions to problems never seen before and a genuine spark of ingenuity.\nTogether, these breakthroughs in competitive programming and mathematical reasoning demonstrate Gemini’s profound leap in abstract problem-solving — marking a significant step on our path toward artificial general intelligence (AGI).\nICPC sets a global standard for excellence\nThe ICPC is globally recognized as the oldest, largest and most prestigious algorithmic programming competition at college level. This is a step up from high school level olympiads such as the IMO. Every year, participants from nearly 3000 universities and over 103 countries compete in solving real-world coding problems.\nThis year’s world finals took place in Baku, Azerbaijan on September 4, and brought together the top teams from earlier phases of the competition. Over a five-hour period, each team tackled a set of complex algorithmic problems. Final rankings hinged on two unforgiving principles: only perfect solutions earned points, and every minute counted. From the 139 competing teams, only the top four teams won gold medals.\nGemini solved 10 of 12 problems, achieving gold-medal level\nAn advanced version of Gemini 2.5 Deep Think competed live in a remote online environment following ICPC rules, under the guidance of the competition organizers. It started 10 minutes after the human contestants and correctly solved 10 out of 12 problems, achieving gold-medal level performance under the same five-hour time constraint. See our solutions here.\nGemini solved eight problems within just 45 minutes and two more problems within three hours, using a wide variety of advanced data structures and algorithms to generate its solutions. By solving 10 problems in a combined total time of 677 minutes, Gemini 2.5 Deep Think would be ranked in 2nd place overall, if compared with the university teams in the competition.\nDr. Bill Poucher, ICPC Global Executive Director, stated: “The ICPC has always been about setting the highest standards in problem solving. Gemini successfully joining this arena, and achieving gold-level results, marks a key moment in defining the AI tools and academic standards needed for the next generation. Congratulations to Google DeepMind; this work will help us fuel a digital renaissance for the benefit of all.”\nGemini solved a problem no university team solved\nIn an unprecedented moment, our model successfully and efficiently solved Problem C within the first half hour — which no university teams in the contest solved.\nProblem C required finding a solution for distributing liquid through a network of interconnected ducts to a set of reservoirs, with the goal of finding a configuration of these ducts that fills all the reservoirs as quickly as possible. There are an infinite number of possible configurations, as each duct may be open, closed or even partially open, making it very difficult to search for the optimal configuration.\nGemini found an effective solution with a clever insight: it first assumed each reservoir has a "priority value" representi ...
#    'summary': None,
#    'score': 0.0,
#    'risk': 'no-summary',
#    'grounded': False},
#   {'title': 'Depop launches a fashion collaging tool to style Pinterest-worthy outfits',
#    'link': 'https://techcrunch.com/2025/09/24/depop-launches-a-fashion-collaging-tool-to-style-pinterest-worthy-outfits/',
#    'category': 'Tech',
#    'text': 'Fashion resale app Depop announced on Wednesday the launch of a new styling and collaging tool, designed specifically for users who love creating fashion collages. Named “Outfits,” the new feature provides a moodboard-like interface, allowing users to design curated outfits to share with followers or inspire their next look.\nTo use the feature, users can select an item they wish to style and click on the scissors icon located on the right side of the screen. This opens up a range of customization options, including the ability to add a colorful background and adjust the sizing and placement of images. There are also templates to use as a layout guide.\nAll items featured in the collages are shoppable, and if a specific item sells out, the app offers suggestions for similar alternatives, the company notes.\nThe addition gives sellers an opportunity to highlight items currently for sale and present them in styled collages, inspiring potential buyers to see how the clothing and accessories can be paired together.\nAdditionally, users can share static images of their curated outfits across various social media platforms, such as Pinterest and Instagram. This appears to be a strategic effort by Depop to appeal to its Gen Z userbase, as collages have become increasingly popular among young users.\nPinterest, for instance, introduced its own collage-making app called Shuffles in 2022 and integrated Shuffles functionality into its main app shortly after.\nDepop says the new Outfits feature is currently available to all users within the Depop app.\nJoin 10k+ tech and VC leaders for growth and connections at Disrupt 2025\nNetflix, Box, a16z, ElevenLabs, Wayve, Sequoia Capital, Elad Gil — just some of the 250+ heavy hitters leading 200+ sessions designed to deliver the insights that fuel startup growth and sharpen your edge. Don’t miss the 20th anniversary of TechCrunch, and a chance to learn from the top voices in tech. Grab your ticket before Sept 26 to save up to $668.\nJoin 10k+ tech and VC leaders for growth and connections at Disrupt 2025\nNetflix, Box, a16z, ElevenLabs, Wayve, Sequoia Capital, Elad Gil — just some of the 250+ heavy hitters leading 200+ sessions designed to deliver the insights that fuel startup growth and sharpen your edge. Don’t miss the 20th anniversary of TechCrunch, and a chance to learn from the top voices in tech. Grab your ticket before Sept 26 to save up to $668.\nThe announcement comes on the heels of parent company Etsy reporting its Q2 2025 earnings, revealing that Depop’s Gross Merchandise Sales (GMS) increased by 34.7% year-over-year on a currency-neutral basis. This growth puts Depop on track for a $1 billion GMS run rate.\nIn comparison, rival Mercari reported a Gross Merchandise Value (GMV) of $728 million for the fourth quarter of 2024.',
#    'summary': None,
#    'score': 0.0,
#    'risk': 'no-summary',
#    'grounded': False},
#   {'title': 'Morgan Stanley downgrades Adobe to Equal-weight over concerns of gen-AI monetization',
#    'link': 'https://seekingalpha.com/news/4498353-morgan-stanley-downgrades-adobe-to-equal-weight-over-concerns-of-gen-ai-monetization?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news',
#    'category': 'Finance',
#    'text': 'Adobe (NASDAQ:ADBE) was downgraded to Equal-weight from Overweight by Morgan Stanley due to unknowns surrounding the software company\'s ability to effectively monetize generative artificial intelligence.\n"Our prior OW thesis on Adobe was predicated on the ability for the company to successfully',
#    'summary': None,
#    'score': 0.0,
#    'risk': 'no-summary',
#    'grounded': False},
#   {'title': 'Using AI to perceive the universe in greater depth',
#    'link': 'https://deepmind.google/discover/blog/using-ai-to-perceive-the-universe-in-greater-depth/',
#    'category': 'AI',
#    'text': 'Science\nUsing AI to perceive the universe in greater depth\nOur novel Deep Loop Shaping method improves control of gravitational wave observatories, helping astronomers better understand the dynamics and formation of the universe.\nTo help astronomers study the universe’s most powerful processes, our teams have been using AI to stabilize one of the most sensitive observation instruments ever built.\nIn a paper published today in Science, we introduce Deep Loop Shaping, a novel AI method that will unlock next-generation gravitational-wave science. Deep Loop Shaping reduces noise and improves control in an observatory’s feedback system, helping stabilize components used for measuring gravitational waves — the tiny ripples in the fabric of space and time.\nThese waves are generated by events like neutron star collisions and black hole mergers. Our method will help astronomers gather data critical to understanding the dynamics and formation of the universe, and better test fundamental theories of physics and cosmology.\nWe developed Deep Loop Shaping in collaboration with LIGO (Laser Interferometer Gravitational-Wave Observatory) operated by Caltech, and GSSI (Gran Sasso Science Institute), and proved our method at the observatory in Livingston, Louisiana.\nLIGO measures the properties and origins of gravitational waves with incredible accuracy. But the slightest vibration can disrupt its measurements, even from waves crashing 100 miles away on the Gulf coast. To function, LIGO relies on thousands of control systems keeping every part in near-perfect alignment, and adapts to environmental disturbances with continuous feedback.\nDeep Loop Shaping reduces the noise level in the most unstable and difficult feedback loop at LIGO by 30 to 100 times, improving the stability of its highly-sensitive interferometer mirrors. Applying our method to all of LIGO’s mirror control loops could help astronomers detect and gather data about hundreds of more events per year, in far greater detail.\nIn the future, Deep Loop Shaping could also be applied to many other engineering problems involving vibration suppression, noise cancellation and highly dynamic or unstable systems important in aerospace, robotics, and structural engineering.\nMeasuring across the universe\nLIGO uses the interference of laser light to measure the properties of gravitational waves. By studying these properties, scientists can figure out what caused them and where they came from. The observatory’s lasers reflect off mirrors positioned 4 kilometers apart, housed in the world’s largest vacuum chambers.\nSince first detecting gravitational waves produced by a pair of colliding black holes, in 2015, verifying the predictions of Albert Einstein’s general theory of relativity, LIGO’s measurements have deeply changed our understanding of the universe.\nWith this observatory, astronomers have detected hundreds of black hole and neutron star collisions, proven the existence of binary black hole systems, seen new black holes formed in neutron star collisions, studied the creation of heavy elements like gold and more.\nAstronomers already know a lot about the largest and smallest black holes, but we only have limited data on intermediate-mass black holes — considered the “missing link” to understanding galaxy evolution.\nUntil now, LIGO has only been capable of observing very few of these systems. To help astronomers capture more detail and data of this phenomena, we worked to improve the most difficult part of the control system and expand how far away we can see these events.\nReducing noise and stabilizing the system\nAs gravitational waves pass through LIGO’s two 4 kilometer arms, they warp the space between them, changing the distance between the mirrors at either end. These tiny differences in length are measured using light interference to an accuracy of 10^-19 meters, which is 1/10’000 the size of a proton. With measurements this small, LIGO’s detector mirrors mus ...
#    'summary': None,
#    'score': 0.0,
#    'risk': 'no-summary',
#    'grounded': False}],
#  'top_n': 10,
#  'digest_md': '# Daily AI • Tech • Finance — 2025-09-24\n\n## AI\n### [Strengthening our Frontier Safety Framework](https://deepmind.google/discover/blog/strengthening-our-frontier-safety-framework/)  \n*Needs-check⚠️ • risk=no-summary*\n(no summary)\n\n### [Discovering new solutions to century-old problems in fluid dynamics](https://deepmind.google/discover/blog/discovering-new-solutions-to-century-old-problems-in-fluid-dynamics/)  \n*Needs-check⚠️ • risk=no-summary*\n(no summary)\n\n### [Gemini achieves gold-level performance at the International Collegiate Programming Contest World Finals](https://deepmind.google/discover/blog/gemini-achieves-gold-level-performance-at-the-international-collegiate-programming-contest-world-finals/)  \n*Needs-check⚠️ • risk=no-summary*\n(no summary)\n\n### [Using AI to perceive the universe in greater depth](https://deepmind.google/discover/blog/using-ai-to-perceive-the-universe-in-greater-depth/)  \n*Needs-check⚠️ • risk=no-summary*\n(no summary)\n\n## Tech\n### [UK police arrest man linked to ransomware attack that caused airport disruptions in Europe](https://techcrunch.com/2025/09/24/uk-police-arrest-man-linked-to-ransomware-attack-that-caused-airport-disruptions-in-europe/)  \n*Needs-check⚠️ • risk=no-summary*\n(no summary)\n\n### [Alibaba to offer Nvidia’s physical AI development tools in its AI platform](https://techcrunch.com/2025/09/24/alibaba-to-offer-nvidias-physical-ai-development-tools-in-its-ai-platform/)  \n*Needs-check⚠️ • risk=no-summary*\n(no summary)\n\n### [Depop launches a fashion collaging tool to style Pinterest-worthy outfits](https://techcrunch.com/2025/09/24/depop-launches-a-fashion-collaging-tool-to-style-pinterest-worthy-outfits/)  \n*Needs-check⚠️ • risk=no-summary*\n(no summary)\n\n## Finance\n### [Marvell Technology announces additional $5B stock repurchase authorization and $1B accelerated share repurchase program](https://seekingalpha.com/news/4498364-marvell-technology-announces-additional-5b-stock-repurchase-authorization-and-1b-accelerated-share-repurchase-program?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news)  \n*Needs-check⚠️ • risk=no-summary*\n(no summary)\n\n### [Borderlands 4 release delayed on Nintendo Switch 2](https://seekingalpha.com/news/4498340-borderlands-4-release-delayed-on-nintendo-switch-2?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news)  \n*Needs-check⚠️ • risk=no-summary*\n(no summary)\n\n### [Morgan Stanley downgrades Adobe to Equal-weight over concerns of gen-AI monetization](https://seekingalpha.com/news/4498353-morgan-stanley-downgrades-adobe-to-equal-weight-over-concerns-of-gen-ai-monetization?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news)  \n*Needs-check⚠️ • risk=no-summary*\n(no summary)\n'}

# %%
# -----------------------------------------------------------------------------
# Main
# -----------------------------------------------------------------------------
if __name__ == "__main__":
    app = build_graph()
    result: AgentState = asyncio.run(app.ainvoke({"articles": [], "top_n": TOP_N, "digest_md": None}))
    stamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    out_path = f"daily_digest_{stamp}.md"

    header = f"_(Generated {stamp})_\n\n"
    content = header + (result.get("digest_md") or "(No content)")
    with open(out_path, "w", encoding="utf-8") as f:
        f.write(content)
    print(f"✅ Wrote {out_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 5
#       1 # -----------------------------------------------------------------------------
#       2 # Main
#       3 # -----------------------------------------------------------------------------
#       4 if __name__ == "__main__":
# ----> 5     app = build_graph()
#       6     result: AgentState = asyncio.run(app.ainvoke({"articles": [], "top_n": TOP_N, "digest_md": None}))
#       7     stamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
#
# NameError: name 'build_graph' is not defined

# %% [markdown]
# # -----------------------------------------------------------------------------
# # Main
# # -----------------------------------------------------------------------------
# if __name__ == "__main__":
#     app = build_graph()
#     result: AgentState = asyncio.run(app.ainvoke({"articles": [], "top_n": TOP_N, "digest_md": None}))
#     stamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
#     out_path = f"daily_digest_{stamp}.md"
#
#     header = f"_(Generated {stamp})_\n\n"
#     content = header + (result.get("digest_md") or "(No content)")
#     with open(out_path, "w", encoding="utf-8") as f:
#         f.write(content)
#     print(f"✅ Wrote {out_path}")
